# %% [markdown]
# # **Setup**

# %%
R.version
# Out:
#                _
# platform       x86_64-w64-mingw32
# arch           x86_64
# os             mingw32
# crt            ucrt
# system         x86_64, mingw32
# status
# major          4
# minor          5.0
# year           2025
# month          04
# day            11
# svn rev        88135
# language       R
# version.string R version 4.5.0 (2025-04-11 ucrt)
# nickname       How About a Twenty-Six

# %%
R.version.string
# Out:
# [1] "R version 4.5.0 (2025-04-11 ucrt)"

# %%
# Load CSV Data 

mygrade <- 100
yourgrade <- 50

mygrade - yourgrade
# Out:
# [1] 50

# %%
df = read.table("abalone_original.csv", header=TRUE, sep = ',')
df
# Out:
#      sex length diameter height whole.weight shucked.weight viscera.weight
# 1    M    91    73       19     102.8         44.9          20.2
# 2    M    70    53       18      45.1         19.9           9.7
# 3    F   106    84       27     135.4         51.3          28.3
# 4    M    88    73       25     103.2         43.1          22.8
# 5    I    66    51       16      41.0         17.9           7.9
# 6    I    85    60       19      70.3         28.2          15.5
# 7    F   106    83       30     155.5         47.4          28.3
# 8    F   109    85       25     153.6         58.8          29.9
# 9    M    95    74       25     101.9         43.3          22.5
# 10   F   110    88       30     178.9         62.9          30.2
# 11   F   105    76       28     121.3         38.8          29.5
# 12   M    86    70       22      81.2         33.5          16.2
# 13   M    98    76       27     108.3         43.5          19.0
# ...
